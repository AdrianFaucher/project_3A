# %%
import pandas as pd
import numpy as np
from src.data_treatment_tools import new_CoM_procedure, add_radian_columns

# %%
galaxy1="NGC5128_CenA"
galaxy2="NGC5236_M83"
r_min=0.83
CoM_Name_min="CoM_CenA_M83_0.83"
r_maj=0.70
CoM_Name_min="CoM_CenA_M83_0.70"

# %%
file_path_with_muse = 'data/new_data_lg.csv'
galaxy_df_with_muse = pd.read_csv(file_path_with_muse)

# %% [markdown]
# # Minor Infall

# %%
add_radian_columns(galaxy_df_with_muse)
new_CoM_procedure(galaxy_df_with_muse,galaxy1=galaxy1,galaxy2=galaxy2,m1_barre=r_min)
galaxy_df_with_muse.to_csv("data/data_CoM_CenA_M83_0.83_lg_with_muse.csv")
# Out:
# CoM_NGC5128_CenA_NGC5236_M83_0.83

# %% [markdown]
# # Major Infall

# %%
add_radian_columns(galaxy_df_with_muse)
new_CoM_procedure(galaxy_df_with_muse,galaxy1=galaxy1,galaxy2=galaxy2,m1_barre=r_maj)
galaxy_df_with_muse.to_csv("data/data_CoM_CenA_M83_0.70_lg_with_muse.csv")
# Out:
# CoM_NGC5128_CenA_NGC5236_M83_0.7
